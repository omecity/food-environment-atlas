# %% [markdown]
# ## Gazetteer county data
#
# [National Counties Gazeteer File for U.S. county geographic data, 2017](https://www.census.gov/geographies/reference-files/time-series/geo/gazetteer-files.2017.html#list-tab-264479560)

# %%
from bs4 import BeautifulSoup
import requests 

import pandas as pd

# %%
# National Counties Gazeteer File
with open('../data/2017_Gaz_counties_national.txt') as file:
    lines = file.readlines()
    table_rows = []
    for line in lines:
        row = line.split('\t')
        if row[3][-17:] == ' City and Borough':
            row[3] = row[3][:-17]
        if row[3][-8:] == ' Borough':
            row[3] = row[3][:-8]
        if row[3][-7:] == ' County':
            row[3] = row[3][:-7]
        if row[3][-12:] == ' Census Area':
            row[3] = row[3][:-12]
        if row[3][-5:] == ' city':
            row[3] = row[3][:-5]
        if row[3][-13:] == ' Municipality':
            row[3] = row[3][:-13]
        if row[3][-10:] == ' Municipio':
            row[3] = row[3][:-10]
        if row[3][-7:] == ' Parish':
            row[3] = row[3][:-7]
        table_rows.append(row)

# %%
county_data = pd.DataFrame(table_rows[1:],columns=table_rows[0])

# %%
# Food Environment Atlas does not include PR counties
PR_indices = county_data.loc[county_data['USPS'] == 'PR'].index
county_data = county_data.drop(PR_indices)

# %%
# Rename columns to be consistent
county_data = county_data.rename({
    'USPS': 'State',
    'GEOID': 'FIPS',
    'NAME': 'County',
    county_data.columns[-1]: 'INTPTLONG'
}, axis=1)

# %%
# Remove space from longitude entries
county_data['INTPTLONG'] = county_data['INTPTLONG'].apply(lambda a: float(a))

# %%
county_data
# Out:
#      State   FIPS  ANSICODE      County        ALAND      AWATER ALAND_SQMI  \
# 0       AL  01001  00161526     Autauga   1539614693    25744269    594.449
# 1       AL  01003  00161527     Baldwin   4117605847  1133109409   1589.817
# 2       AL  01005  00161528     Barbour   2292144656    50538698    885.002
# 3       AL  01007  00161529        Bibb   1612165763     9603798    622.461
# 4       AL  01009  00161530      Blount   1670079465    15039864    644.821
# ...    ...    ...       ...         ...          ...         ...        ...
# 3137    WY  56037  01609192  Sweetwater  27005738206   166246301  10426.974
# 3138    WY  56039  01605083       Teton  10351785153   570864021   3996.847
# 3139    WY  56041  01605084       Uinta   5391911952    16345637   2081.829
# 3140    WY  56043  01605085    Washakie   5798120186    10455585   2238.667
# 3141    WY  56045  01605086      Weston   6210804109     5225498   2398.005
#
#      AWATER_SQMI   INTPTLAT   INTPTLONG
# 0           9.94  32.532237  -86.646440
# 1        437.496  30.659218  -87.746067
# 2         19.513  31.870253  -85.405104
# 3          3.708  33.015893  -87.127148
# 4          5.807  33.977358  -86.566440
# ...          ...        ...         ...
# 3137      64.188  41.660328 -108.875677
# 3138     220.412  44.048662 -110.426072
# 3139       6.311  41.284726 -110.558947
# 3140       4.037  43.878831 -107.669052
# 3141       2.018  43.846213 -104.570020
#
# [3142 rows x 10 columns]

# %%
county_data.to_csv('../data/county_census_data.csv', index=False)
